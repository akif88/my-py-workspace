# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(300)
plt.plot(x, 'o')
plt.show()

# %%
x
# Out:
# array([0.72015086, 0.78822042, 0.48178473, 0.1346374 , 0.12037998,
#        0.58317215, 0.8558784 , 0.95278855, 0.59610056, 0.90202294,
#        0.70911398, 0.37595304, 0.02732184, 0.2392273 , 0.0758044 ,
#        0.96401624, 0.82478453, 0.04103177, 0.10485819, 0.13092266,
#        0.14298233, 0.66384395, 0.88651198, 0.50493068, 0.20622125,
#        0.16540117, 0.15586933, 0.55184387, 0.60275412, 0.09809112,
#        0.29312924, 0.77254159, 0.40471916, 0.46428995, 0.49541039,
#        0.73175315, 0.27420783, 0.55204828, 0.06964185, 0.41790989,
#        0.20427833, 0.97756491, 0.49009176, 0.34559761, 0.77115989,
#        0.87886032, 0.52439209, 0.41974151, 0.57536765, 0.16711558,
#        0.75914722, 0.87847812, 0.58643412, 0.44553049, 0.75308838,
#        0.22094313, 0.3815265 , 0.01422763, 0.05306616, 0.3970962 ,
#        0.58728552, 0.30809948, 0.06758148, 0.1369345 , 0.74164764,
#        0.02119083, 0.38058075, 0.69090177, 0.0115035 , 0.60244496,
# ...

# %%
x = list()
x
# Out:
# []
