# %%
import pandas as pd

# %%
filepath = 'data/Iris_Data.csv'

data = pd.read_csv(filepath)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
data['sepal_area'] = data.sepal_width * data.sepal_width
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#
#    sepal_area
# 0       12.25
# 1        9.00
# 2       10.24
# 3        9.61
# 4       12.96
# 5       15.21
# 6       11.56
# 7       11.56
# 8        8.41
# 9        9.61

# %%
data.iloc[:5, -2:] # row 0-5, column 4-5
# Out:
#        species  sepal_area
# 0  Iris-setosa       12.25
# 1  Iris-setosa        9.00
# 2  Iris-setosa       10.24
# 3  Iris-setosa        9.61
# 4  Iris-setosa       12.96

# %%
group_species = data.groupby(data.species)

# %%
group_species.size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
group_species.mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width  \
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026
#
#                  sepal_area
# species
# Iris-setosa         11.8250
# Iris-versicolor      7.7694
# Iris-virginica       8.9466

# %%
data.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# sepal_area      9.513667
# dtype: float64

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_area
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    9.513667
# std        0.828066     0.433594      1.764420     0.763161    2.724134
# min        4.300000     2.000000      1.000000     0.100000    4.000000
# 25%        5.100000     2.800000      1.600000     0.300000    7.840000
# 50%        5.800000     3.000000      4.350000     1.300000    9.000000
# 75%        6.400000     3.300000      5.100000     1.800000   10.890000
# max        7.900000     4.400000      6.900000     2.500000   19.360000

# %%
pd.set_option('display.max_columns',None) # display entire dataframe column
group_species.describe()
# Out:
#                 sepal_length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# species
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal_width                                                \
#                       count   mean       std  min    25%  50%    75%  max
# species
# Iris-setosa            50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor        50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica         50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8
#
#                 petal_length                                               \
#                        count   mean       std  min  25%   50%    75%  max
# species
# ...

# %%
data.sepal_area.mean()
# Out:
# 9.513666666666666

# %%
data.sepal_area.median()
# Out:
# 9.0

# %%
data.sepal_area.mode()
# Out:
# 0    9.0
# dtype: float64

# %%
data.sample(n=10, replace=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 116           6.5          3.0           5.5          1.8   Iris-virginica
# 140           6.7          3.1           5.6          2.4   Iris-virginica
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 2             4.7          3.2           1.3          0.2      Iris-setosa
#
#      sepal_area
# 116        9.00
# 140        9.61
# 94         7.29
# 107        8.41
# 11        11.56
# 72         6.25
# 51        10.24
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(data.sepal_length, data.sepal_width, ls='', marker='o')

# %%
plt.plot(data.sepal_length, data.sepal_width, ls='', marker='o', label='sepal')
plt.plot(data.petal_length, data.petal_width, ls='', marker='o', label='petal')

# %%
plt.hist(data.sepal_length, bins=25)
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <a list of 25 Patch objects>)

# %%
group_species.mean().plot()

# %%
import seaborn as sns
sns.pairplot(data, hue='species', size=3)
# Out:
# /home/akif/miniconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
